# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px
import json

# %% [markdown]
# #  Step 1 :- Problem Statement

# %% [markdown]
# # Step 2 :- Data Wrangling

# %% [markdown]
# There are four datasets in our project
# - 1. Match results dataset
# - 2. Batting dataset
# - 3. Bowling dataset
# - 4. Players dataset

# %% [markdown]
# ##  `Match Results dataset`

# %% [markdown]
# ### Data Gathering

# %%
import numpy as np
import pandas as pd

# %%
# loading data through a json file

with open('data-analytics-project-for-beginners/t20_json_files/t20_wc_match_results.json') as f:
    data = json.load(f)
data
# Out:
# [{'matchSummary': [{'team1': 'Namibia',
#     'team2': 'Sri Lanka',
#     'winner': 'Namibia',
#     'margin': '55 runs',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 16, 2022',
#     'scorecard': 'T20I # 1823'},
#    {'team1': 'Netherlands',
#     'team2': 'U.A.E.',
#     'winner': 'Netherlands',
#     'margin': '3 wickets',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 16, 2022',
#     'scorecard': 'T20I # 1825'},
#    {'team1': 'Scotland',
#     'team2': 'West Indies',
#     'winner': 'Scotland',
#     'margin': '42 runs',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 17, 2022',
#     'scorecard': 'T20I # 1826'},
#    {'team1': 'Ireland',
#     'team2': 'Zimbabwe',
#     'winner': 'Zimbabwe',
#     'margin': '31 runs',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 17, 2022',
#     'scorecard': 'T20I # 1828'},
#    {'team1': 'Namibia',
#     'team2': 'Netherlands',
#     'winner': 'Netherlands',
#     'margin': '5 wickets',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 18, 2022',
#     'scorecard': 'T20I # 1830'},
#    {'team1': 'Sri Lanka',
#     'team2': 'U.A.E.',
#     'winner': 'Sri Lanka',
#     'margin': '79 runs',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 18, 2022',
#     'scorecard': 'T20I # 1832'},
#    {'team1': 'Ireland',
#     'team2': 'Scotland',
#     'winner': 'Ireland',
#     'margin': '6 wickets',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 19, 2022',
#     'scorecard': 'T20I # 1833'},
#    {'team1': 'West Indies',
#     'team2': 'Zimbabwe',
#     'winner': 'West Indies',
#     'margin': '31 runs',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 19, 2022',
#     'scorecard': 'T20I # 1834'},
#    {'team1': 'Netherlands',
#     'team2': 'Sri Lanka',
#     'winner': 'Sri Lanka',
#     'margin': '16 runs',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 20, 2022',
#     'scorecard': 'T20I # 1835'},
#    {'team1': 'Namibia',
#     'team2': 'U.A.E.',
#     'winner': 'U.A.E.',
#     'margin': '7 runs',
#     'ground': 'Geelong',
#     'matchDate': 'Oct 20, 2022',
#     'scorecard': 'T20I # 1836'},
#    {'team1': 'Ireland',
#     'team2': 'West Indies',
#     'winner': 'Ireland',
#     'margin': '9 wickets',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 21, 2022',
#     'scorecard': 'T20I # 1837'},
#    {'team1': 'Scotland',
#     'team2': 'Zimbabwe',
#     'winner': 'Zimbabwe',
#     'margin': '5 wickets',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 21, 2022',
#     'scorecard': 'T20I # 1838'},
#    {'team1': 'Australia',
#     'team2': 'New Zealand',
#     'winner': 'New Zealand',
#     'margin': '89 runs',
#     'ground': 'Sydney',
#     'matchDate': 'Oct 22, 2022',
#     'scorecard': 'T20I # 1839'},
#    {'team1': 'Afghanistan',
#     'team2': 'England',
#     'winner': 'England',
#     'margin': '5 wickets',
#     'ground': 'Perth',
#     'matchDate': 'Oct 22, 2022',
#     'scorecard': 'T20I # 1840'},
#    {'team1': 'Ireland',
#     'team2': 'Sri Lanka',
#     'winner': 'Sri Lanka',
#     'margin': '9 wickets',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 23, 2022',
#     'scorecard': 'T20I # 1841'},
#    {'team1': 'India',
#     'team2': 'Pakistan',
#     'winner': 'India',
#     'margin': '4 wickets',
#     'ground': 'Melbourne',
#     'matchDate': 'Oct 23, 2022',
#     'scorecard': 'T20I # 1842'},
#    {'team1': 'Bangladesh',
#     'team2': 'Netherlands',
#     'winner': 'Bangladesh',
#     'margin': '9 runs',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 24, 2022',
#     'scorecard': 'T20I # 1843'},
#    {'team1': 'South Africa',
#     'team2': 'Zimbabwe',
#     'winner': 'no result',
#     'margin': '',
#     'ground': 'Hobart',
#     'matchDate': 'Oct 24, 2022',
#     'scorecard': 'T20I # 1844'},
#    {'team1': 'Australia',
#     'team2': 'Sri Lanka',
#     'winner': 'Australia',
#     'margin': '7 wickets',
#     'ground': 'Perth',
#     'matchDate': 'Oct 25, 2022',
#     'scorecard': 'T20I # 1845'},
#    {'team1': 'England',
#     'team2': 'Ireland',
#     'winner': 'Ireland',
#     'margin': '5 runs',
#     'ground': 'Melbourne',
#     'matchDate': 'Oct 26, 2022',
#     'scorecard': 'T20I # 1846'},
#    {'team1': 'Afghanistan',
#     'team2': 'New Zealand',
#     'winner': 'abandoned',
#     'margin': '',
#     'ground': 'Melbourne',
#     'matchDate': 'Oct 26, 2022',
#     'scorecard': 'T20I # 1846a'},
#    {'team1': 'Bangladesh',
#     'team2': 'South Africa',
#     'winner': 'South Africa',
#     'margin': '104 runs',
#     'ground': 'Sydney',
#     'matchDate': 'Oct 27, 2022',
#     'scorecard': 'T20I # 1847'},
#    {'team1': 'India',
#     'team2': 'Netherlands',
#     'winner': 'India',
#     'margin': '56 runs',
#     'ground': 'Sydney',
#     'matchDate': 'Oct 27, 2022',
#     'scorecard': 'T20I # 1848'},
#    {'team1': 'Pakistan',
#     'team2': 'Zimbabwe',
#     'winner': 'Zimbabwe',
#     'margin': '1 run',
#     'ground': 'Perth',
#     'matchDate': 'Oct 27, 2022',
#     'scorecard': 'T20I # 1849'},
#    {'team1': 'Afghanistan',
#     'team2': 'Ireland',
#     'winner': 'abandoned',
#     'margin': '',
#     'ground': 'Melbourne',
#     'matchDate': 'Oct 28, 2022',
#     'scorecard': 'T20I # 1849a'},
#    {'team1': 'Australia',
#     'team2': 'England',
#     'winner': 'abandoned',
#     'margin': '',
#     'ground': 'Melbourne',
#     'matchDate': 'Oct 28, 2022',
#     'scorecard': 'T20I # 1849b'},
#    {'team1': 'New Zealand',
#     'team2': 'Sri Lanka',
#     'winner': 'New Zealand',
#     'margin': '65 runs',
#     'ground': 'Sydney',
#     'matchDate': 'Oct 29, 2022',
#     'scorecard': 'T20I # 1850'},
#    {'team1': 'Bangladesh',
#     'team2': 'Zimbabwe',
#     'winner': 'Bangladesh',
#     'margin': '3 runs',
#     'ground': 'Brisbane',
#     'matchDate': 'Oct 30, 2022',
#     'scorecard': 'T20I # 1851'},
#    {'team1': 'Netherlands',
#     'team2': 'Pakistan',
#     'winner': 'Pakistan',
#     'margin': '6 wickets',
#     'ground': 'Perth',
#     'matchDate': 'Oct 30, 2022',
#     'scorecard': 'T20I # 1852'},
#    {'team1': 'India',
#     'team2': 'South Africa',
#     'winner': 'South Africa',
#     'margin': '5 wickets',
#     'ground': 'Perth',
#     'matchDate': 'Oct 30, 2022',
#     'scorecard': 'T20I # 1853'},
#    {'team1': 'Australia',
#     'team2': 'Ireland',
#     'winner': 'Australia',
#     'margin': '42 runs',
#     'ground': 'Brisbane',
#     'matchDate': 'Oct 31, 2022',
#     'scorecard': 'T20I # 1855'},
#    {'team1': 'Afghanistan',
#     'team2': 'Sri Lanka',
#     'winner': 'Sri Lanka',
#     'margin': '6 wickets',
#     'ground': 'Brisbane',
#     'matchDate': 'Nov 1, 2022',
#     'scorecard': 'T20I # 1856'},
#    {'team1': 'England',
#     'team2': 'New Zealand',
#     'winner': 'England',
#     'margin': '20 runs',
#     'ground': 'Brisbane',
#     'matchDate': 'Nov 1, 2022',
#     'scorecard': 'T20I # 1858'},
#    {'team1': 'Netherlands',
#     'team2': 'Zimbabwe',
#     'winner': 'Netherlands',
#     'margin': '5 wickets',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 2, 2022',
#     'scorecard': 'T20I # 1859'},
#    {'team1': 'Bangladesh',
#     'team2': 'India',
#     'winner': 'India',
#     'margin': '5 runs',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 2, 2022',
#     'scorecard': 'T20I # 1860'},
#    {'team1': 'Pakistan',
#     'team2': 'South Africa',
#     'winner': 'Pakistan',
#     'margin': '33 runs',
#     'ground': 'Sydney',
#     'matchDate': 'Nov 3, 2022',
#     'scorecard': 'T20I # 1861'},
#    {'team1': 'Ireland',
#     'team2': 'New Zealand',
#     'winner': 'New Zealand',
#     'margin': '35 runs',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 4, 2022',
#     'scorecard': 'T20I # 1862'},
#    {'team1': 'Australia',
#     'team2': 'Afghanistan',
#     'winner': 'Australia',
#     'margin': '4 runs',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 4, 2022',
#     'scorecard': 'T20I # 1864'},
#    {'team1': 'England',
#     'team2': 'Sri Lanka',
#     'winner': 'England',
#     'margin': '4 wickets',
#     'ground': 'Sydney',
#     'matchDate': 'Nov 5, 2022',
#     'scorecard': 'T20I # 1867'},
#    {'team1': 'Netherlands',
#     'team2': 'South Africa',
#     'winner': 'Netherlands',
#     'margin': '13 runs',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 6, 2022',
#     'scorecard': 'T20I # 1871'},
#    {'team1': 'Bangladesh',
#     'team2': 'Pakistan',
#     'winner': 'Pakistan',
#     'margin': '5 wickets',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 6, 2022',
#     'scorecard': 'T20I # 1872'},
#    {'team1': 'India',
#     'team2': 'Zimbabwe',
#     'winner': 'India',
#     'margin': '71 runs',
#     'ground': 'Melbourne',
#     'matchDate': 'Nov 6, 2022',
#     'scorecard': 'T20I # 1873'},
#    {'team1': 'New Zealand',
#     'team2': 'Pakistan',
#     'winner': 'Pakistan',
#     'margin': '7 wickets',
#     'ground': 'Sydney',
#     'matchDate': 'Nov 9, 2022',
#     'scorecard': 'T20I # 1877'},
#    {'team1': 'England',
#     'team2': 'India',
#     'winner': 'England',
#     'margin': '10 wickets',
#     'ground': 'Adelaide',
#     'matchDate': 'Nov 10, 2022',
#     'scorecard': 'T20I # 1878'},
#    {'team1': 'England',
#     'team2': 'Pakistan',
#     'winner': 'England',
#     'margin': '5 wickets',
#     'ground': 'Melbourne',
#     'matchDate': 'Nov 13, 2022',
#     'scorecard': 'T20I # 1879'}]}]

# %%
len(data)

# we can see that the data has only one element
# then futther the inside dictionary also has single element 
# where our data is present
# Out:
# 1

# %%
data[0]['matchSummary']    # this is our data so convert it to a dataframe
# Out:
# [{'team1': 'Namibia',
#   'team2': 'Sri Lanka',
#   'winner': 'Namibia',
#   'margin': '55 runs',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 16, 2022',
#   'scorecard': 'T20I # 1823'},
#  {'team1': 'Netherlands',
#   'team2': 'U.A.E.',
#   'winner': 'Netherlands',
#   'margin': '3 wickets',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 16, 2022',
#   'scorecard': 'T20I # 1825'},
#  {'team1': 'Scotland',
#   'team2': 'West Indies',
#   'winner': 'Scotland',
#   'margin': '42 runs',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 17, 2022',
#   'scorecard': 'T20I # 1826'},
#  {'team1': 'Ireland',
#   'team2': 'Zimbabwe',
#   'winner': 'Zimbabwe',
#   'margin': '31 runs',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 17, 2022',
#   'scorecard': 'T20I # 1828'},
#  {'team1': 'Namibia',
#   'team2': 'Netherlands',
#   'winner': 'Netherlands',
#   'margin': '5 wickets',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 18, 2022',
#   'scorecard': 'T20I # 1830'},
#  {'team1': 'Sri Lanka',
#   'team2': 'U.A.E.',
#   'winner': 'Sri Lanka',
#   'margin': '79 runs',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 18, 2022',
#   'scorecard': 'T20I # 1832'},
#  {'team1': 'Ireland',
#   'team2': 'Scotland',
#   'winner': 'Ireland',
#   'margin': '6 wickets',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 19, 2022',
#   'scorecard': 'T20I # 1833'},
#  {'team1': 'West Indies',
#   'team2': 'Zimbabwe',
#   'winner': 'West Indies',
#   'margin': '31 runs',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 19, 2022',
#   'scorecard': 'T20I # 1834'},
#  {'team1': 'Netherlands',
#   'team2': 'Sri Lanka',
#   'winner': 'Sri Lanka',
#   'margin': '16 runs',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 20, 2022',
#   'scorecard': 'T20I # 1835'},
#  {'team1': 'Namibia',
#   'team2': 'U.A.E.',
#   'winner': 'U.A.E.',
#   'margin': '7 runs',
#   'ground': 'Geelong',
#   'matchDate': 'Oct 20, 2022',
#   'scorecard': 'T20I # 1836'},
#  {'team1': 'Ireland',
#   'team2': 'West Indies',
#   'winner': 'Ireland',
#   'margin': '9 wickets',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 21, 2022',
#   'scorecard': 'T20I # 1837'},
#  {'team1': 'Scotland',
#   'team2': 'Zimbabwe',
#   'winner': 'Zimbabwe',
#   'margin': '5 wickets',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 21, 2022',
#   'scorecard': 'T20I # 1838'},
#  {'team1': 'Australia',
#   'team2': 'New Zealand',
#   'winner': 'New Zealand',
#   'margin': '89 runs',
#   'ground': 'Sydney',
#   'matchDate': 'Oct 22, 2022',
#   'scorecard': 'T20I # 1839'},
#  {'team1': 'Afghanistan',
#   'team2': 'England',
#   'winner': 'England',
#   'margin': '5 wickets',
#   'ground': 'Perth',
#   'matchDate': 'Oct 22, 2022',
#   'scorecard': 'T20I # 1840'},
#  {'team1': 'Ireland',
#   'team2': 'Sri Lanka',
#   'winner': 'Sri Lanka',
#   'margin': '9 wickets',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 23, 2022',
#   'scorecard': 'T20I # 1841'},
#  {'team1': 'India',
#   'team2': 'Pakistan',
#   'winner': 'India',
#   'margin': '4 wickets',
#   'ground': 'Melbourne',
#   'matchDate': 'Oct 23, 2022',
#   'scorecard': 'T20I # 1842'},
#  {'team1': 'Bangladesh',
#   'team2': 'Netherlands',
#   'winner': 'Bangladesh',
#   'margin': '9 runs',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 24, 2022',
#   'scorecard': 'T20I # 1843'},
#  {'team1': 'South Africa',
#   'team2': 'Zimbabwe',
#   'winner': 'no result',
#   'margin': '',
#   'ground': 'Hobart',
#   'matchDate': 'Oct 24, 2022',
#   'scorecard': 'T20I # 1844'},
#  {'team1': 'Australia',
#   'team2': 'Sri Lanka',
#   'winner': 'Australia',
#   'margin': '7 wickets',
#   'ground': 'Perth',
#   'matchDate': 'Oct 25, 2022',
#   'scorecard': 'T20I # 1845'},
#  {'team1': 'England',
#   'team2': 'Ireland',
#   'winner': 'Ireland',
#   'margin': '5 runs',
#   'ground': 'Melbourne',
#   'matchDate': 'Oct 26, 2022',
#   'scorecard': 'T20I # 1846'},
#  {'team1': 'Afghanistan',
#   'team2': 'New Zealand',
#   'winner': 'abandoned',
#   'margin': '',
#   'ground': 'Melbourne',
#   'matchDate': 'Oct 26, 2022',
#   'scorecard': 'T20I # 1846a'},
#  {'team1': 'Bangladesh',
#   'team2': 'South Africa',
#   'winner': 'South Africa',
#   'margin': '104 runs',
#   'ground': 'Sydney',
#   'matchDate': 'Oct 27, 2022',
#   'scorecard': 'T20I # 1847'},
#  {'team1': 'India',
#   'team2': 'Netherlands',
#   'winner': 'India',
#   'margin': '56 runs',
#   'ground': 'Sydney',
#   'matchDate': 'Oct 27, 2022',
#   'scorecard': 'T20I # 1848'},
#  {'team1': 'Pakistan',
#   'team2': 'Zimbabwe',
#   'winner': 'Zimbabwe',
#   'margin': '1 run',
#   'ground': 'Perth',
#   'matchDate': 'Oct 27, 2022',
#   'scorecard': 'T20I # 1849'},
#  {'team1': 'Afghanistan',
#   'team2': 'Ireland',
#   'winner': 'abandoned',
#   'margin': '',
#   'ground': 'Melbourne',
#   'matchDate': 'Oct 28, 2022',
#   'scorecard': 'T20I # 1849a'},
#  {'team1': 'Australia',
#   'team2': 'England',
#   'winner': 'abandoned',
#   'margin': '',
#   'ground': 'Melbourne',
#   'matchDate': 'Oct 28, 2022',
#   'scorecard': 'T20I # 1849b'},
#  {'team1': 'New Zealand',
#   'team2': 'Sri Lanka',
#   'winner': 'New Zealand',
#   'margin': '65 runs',
#   'ground': 'Sydney',
#   'matchDate': 'Oct 29, 2022',
#   'scorecard': 'T20I # 1850'},
#  {'team1': 'Bangladesh',
#   'team2': 'Zimbabwe',
#   'winner': 'Bangladesh',
#   'margin': '3 runs',
#   'ground': 'Brisbane',
#   'matchDate': 'Oct 30, 2022',
#   'scorecard': 'T20I # 1851'},
#  {'team1': 'Netherlands',
#   'team2': 'Pakistan',
#   'winner': 'Pakistan',
#   'margin': '6 wickets',
#   'ground': 'Perth',
#   'matchDate': 'Oct 30, 2022',
#   'scorecard': 'T20I # 1852'},
#  {'team1': 'India',
#   'team2': 'South Africa',
#   'winner': 'South Africa',
#   'margin': '5 wickets',
#   'ground': 'Perth',
#   'matchDate': 'Oct 30, 2022',
#   'scorecard': 'T20I # 1853'},
#  {'team1': 'Australia',
#   'team2': 'Ireland',
#   'winner': 'Australia',
#   'margin': '42 runs',
#   'ground': 'Brisbane',
#   'matchDate': 'Oct 31, 2022',
#   'scorecard': 'T20I # 1855'},
#  {'team1': 'Afghanistan',
#   'team2': 'Sri Lanka',
#   'winner': 'Sri Lanka',
#   'margin': '6 wickets',
#   'ground': 'Brisbane',
#   'matchDate': 'Nov 1, 2022',
#   'scorecard': 'T20I # 1856'},
#  {'team1': 'England',
#   'team2': 'New Zealand',
#   'winner': 'England',
#   'margin': '20 runs',
#   'ground': 'Brisbane',
#   'matchDate': 'Nov 1, 2022',
#   'scorecard': 'T20I # 1858'},
#  {'team1': 'Netherlands',
#   'team2': 'Zimbabwe',
#   'winner': 'Netherlands',
#   'margin': '5 wickets',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 2, 2022',
#   'scorecard': 'T20I # 1859'},
#  {'team1': 'Bangladesh',
#   'team2': 'India',
#   'winner': 'India',
#   'margin': '5 runs',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 2, 2022',
#   'scorecard': 'T20I # 1860'},
#  {'team1': 'Pakistan',
#   'team2': 'South Africa',
#   'winner': 'Pakistan',
#   'margin': '33 runs',
#   'ground': 'Sydney',
#   'matchDate': 'Nov 3, 2022',
#   'scorecard': 'T20I # 1861'},
#  {'team1': 'Ireland',
#   'team2': 'New Zealand',
#   'winner': 'New Zealand',
#   'margin': '35 runs',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 4, 2022',
#   'scorecard': 'T20I # 1862'},
#  {'team1': 'Australia',
#   'team2': 'Afghanistan',
#   'winner': 'Australia',
#   'margin': '4 runs',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 4, 2022',
#   'scorecard': 'T20I # 1864'},
#  {'team1': 'England',
#   'team2': 'Sri Lanka',
#   'winner': 'England',
#   'margin': '4 wickets',
#   'ground': 'Sydney',
#   'matchDate': 'Nov 5, 2022',
#   'scorecard': 'T20I # 1867'},
#  {'team1': 'Netherlands',
#   'team2': 'South Africa',
#   'winner': 'Netherlands',
#   'margin': '13 runs',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 6, 2022',
#   'scorecard': 'T20I # 1871'},
#  {'team1': 'Bangladesh',
#   'team2': 'Pakistan',
#   'winner': 'Pakistan',
#   'margin': '5 wickets',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 6, 2022',
#   'scorecard': 'T20I # 1872'},
#  {'team1': 'India',
#   'team2': 'Zimbabwe',
#   'winner': 'India',
#   'margin': '71 runs',
#   'ground': 'Melbourne',
#   'matchDate': 'Nov 6, 2022',
#   'scorecard': 'T20I # 1873'},
#  {'team1': 'New Zealand',
#   'team2': 'Pakistan',
#   'winner': 'Pakistan',
#   'margin': '7 wickets',
#   'ground': 'Sydney',
#   'matchDate': 'Nov 9, 2022',
#   'scorecard': 'T20I # 1877'},
#  {'team1': 'England',
#   'team2': 'India',
#   'winner': 'England',
#   'margin': '10 wickets',
#   'ground': 'Adelaide',
#   'matchDate': 'Nov 10, 2022',
#   'scorecard': 'T20I # 1878'},
#  {'team1': 'England',
#   'team2': 'Pakistan',
#   'winner': 'England',
#   'margin': '5 wickets',
#   'ground': 'Melbourne',
#   'matchDate': 'Nov 13, 2022',
#   'scorecard': 'T20I # 1879'}]

# %%
# convert it into a dataframe

df_matches = pd.DataFrame(data[0]['matchSummary'])

# %% [markdown]
# ### Data Cleaning

# %%
df_matches.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#      scorecard
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
df_matches.shape
# Out:
# (45, 7)

# %%
# here we don't want to access the scorecard, so instead of scorecard we rename that column as match_id

df_matches.rename({'scorecard':'match_id'}, axis=1, inplace=True)
df_matches.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#       match_id
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %% [markdown]
# ##  `Batting Records dataset`

# %% [markdown]
# ### Data Gathering

# %%
with open('data-analytics-project-for-beginners/t20_json_files/t20_wc_batting_summary.json') as f:
    data = json.load(f)
    
    all_records = []
    
    for rec in data:
        all_records.extend(rec['battingSummary'])
        
df_batting = pd.DataFrame(all_records)

# %% [markdown]
# ### Data Cleaning

# %%
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
#
#                          dismissal runs balls 4s 6s      SR
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00
# 2        c â€ Mendis b Karunaratne   20    12  1  2  166.66
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33

# %%
df_batting.shape
# Out:
# (699, 10)

# %%
# the dissmissal column contains some blank values and a record of that wicket,
# we just wants that the batsman is out or not
# so replacing values by out and blank/null values by not out

df_batting['dismissed'] = df_batting.dismissal.apply(lambda x: '1' if len(x)>0 else '0')
df_batting.head(20)
# Out:
#                     match teamInnings  battingPos                 batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1          Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2               Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3      Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4               Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5          Gerhard Erasmus(c)
# 5    Namibia Vs Sri Lanka     Namibia           6                Jan Frylinck
# 6    Namibia Vs Sri Lanka     Namibia           7                 David Wiese
# 7    Namibia Vs Sri Lanka     Namibia           8                     JJ Smit
# 8    Namibia Vs Sri Lanka   Sri Lanka           1             Pathum Nissanka
# 9    Namibia Vs Sri Lanka   Sri Lanka           2             Kusal Mendisâ€
# 10   Namibia Vs Sri Lanka   Sri Lanka           3         Dhananjaya de Silva
# 11   Namibia Vs Sri Lanka   Sri Lanka           4        Danushka Gunathilaka
# 12   Namibia Vs Sri Lanka   Sri Lanka           5           Bhanuka Rajapaksa
# 13   Namibia Vs Sri Lanka   Sri Lanka           6            Dasun Shanaka(c)
# 14   Namibia Vs Sri Lanka   Sri Lanka           7  Wanindu Hasaranga de Silva
# 15   Namibia Vs Sri Lanka   Sri Lanka           8         Chamika Karunaratne
# 16   Namibia Vs Sri Lanka   Sri Lanka           9             Pramod Madushan
# 17   Namibia Vs Sri Lanka   Sri Lanka          10         Dushmantha Chameera
# 18   Namibia Vs Sri Lanka   Sri Lanka          11          Maheesh Theekshana
# 19  U.A.E. Vs Netherlands      U.A.E.           1                 Chirag Suri
#
#                           dismissal runs balls 4s 6s      SR dismissed
# 0      c Pramod Madushan b Chameera    3     6  0  0   50.00         1
# 1       c Shanaka b Pramod Madushan    9     9  1  0  100.00         1
# 2         c â€ Mendis b Karunaratne   20    12  1  2  166.66         1
# 3   c DM de Silva b Pramod Madushan   26    24  2  0  108.33         1
# 4      c Gunathilaka b PWH de Silva   20    24  0  0   83.33         1
# 5   run out (Gunathilaka/â€ Mendis)   44    28  4  0  157.14         1
# 6          c â€ Mendis b Theekshana    0     1  0  0    0.00         1
# 7                                     31    16  2  2  193.75         0
# 8                 c Smit b Shikongo    9    10  1  0   90.00         1
# 9                c â€ Green b Wiese    6     6  0  0  100.00         1
# 10            c Shikongo b Frylinck   12    11  1  0  109.09         1
# 11            c â€ Green b Shikongo    0     1  0  0    0.00         1
# 12              c la Cock b Scholtz   20    21  2  0   95.23         1
# 13            c â€ Green b Frylinck   29    23  2  1  126.08         1
# 14         c Loftie-Eaton b Scholtz    4     8  0  0   50.00         1
# 15                   c Baard b Smit    5     8  0  0   62.50         1
# 16    run out (van Lingen/â€ Green)    0     0  0  0       -         1
# 17                c Erasmus b Wiese    8    15  0  0   53.33         1
# 18                                    11    11  0  1  100.00         0
# 19     c â€ Edwards b van der Merwe   12    20  1  0   60.00         1

# %%
# there are some special characters in players names which should be cleaned


df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x : x.replace('â€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x : x.replace('\xa0', ''))
df_batting.head(10)
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# 5  Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck
# 6  Namibia Vs Sri Lanka     Namibia           7             David Wiese
# 7  Namibia Vs Sri Lanka     Namibia           8                 JJ Smit
# 8  Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka
# 9  Namibia Vs Sri Lanka   Sri Lanka           2            Kusal Mendis
#
#                          dismissal runs balls 4s 6s      SR dismissed
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00         1
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00         1
# 2        c â€ Mendis b Karunaratne   20    12  1  2  166.66         1
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33         1
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33         1
# 5  run out (Gunathilaka/â€ Mendis)   44    28  4  0  157.14         1
# 6         c â€ Mendis b Theekshana    0     1  0  0    0.00         1
# 7                                    31    16  2  2  193.75         0
# 8                c Smit b Shikongo    9    10  1  0   90.00         1
# 9               c â€ Green b Wiese    6     6  0  0  100.00         1

# %%
# there is no column in df_batting table that matches with any column in df_matches
# so, we are getting two columns of team names from df_matches dataframe
# combines it with its match id into a dictionary
# and create a match_id column into df_batting table

match_id_dict = {}

for key, row in df_matches.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    
    match_id_dict[key1] = row['match_id']
    match_id_dict[key2] = row['match_id']

# %%
df_batting['match_id'] = df_batting['match'].map(match_id_dict) # adds each value from dict to match_id by mapping match values to subsequent keys in dict

df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
#
#                          dismissal runs balls 4s 6s      SR dismissed  \
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00         1
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00         1
# 2        c â€ Mendis b Karunaratne   20    12  1  2  166.66         1
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33         1
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33         1
#
#       match_id
# 0  T20I # 1823
# 1  T20I # 1823
# 2  T20I # 1823
# 3  T20I # 1823
# 4  T20I # 1823

# %% [markdown]
# ## `Bowling Records Dataset`

# %% [markdown]
# ### Data Gathering

# %%
with open('data-analytics-project-for-beginners/t20_json_files/t20_wc_bowling_summary.json') as f:
    data = json.load(f)
    
    all_records = []
    
    for rec in data:
        all_records.extend(rec['bowlingSummary'])
        
df_bowling = pd.DataFrame(all_records)

# %% [markdown]
# ### Data Cleaning

# %%
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls
# 0   23       1    5.75  7  0  0     2       0
# 1   39       1    9.75  6  3  1     2       0
# 2   37       2    9.25  6  3  1     0       0
# 3   36       1    9.00  7  3  1     1       0
# 4   27       1    6.75  8  1  1     0       0

# %%
# creating a match_id column 

df_bowling['match_id'] = df_bowling['match'].map(match_id_dict)

df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls     match_id
# 0   23       1    5.75  7  0  0     2       0  T20I # 1823
# 1   39       1    9.75  6  3  1     2       0  T20I # 1823
# 2   37       2    9.25  6  3  1     0       0  T20I # 1823
# 3   36       1    9.00  7  3  1     1       0  T20I # 1823
# 4   27       1    6.75  8  1  1     0       0  T20I # 1823

# %% [markdown]
# ## `Player Records Dataset`

# %% [markdown]
# ### Data Gathering

# %%
with open('data-analytics-project-for-beginners/t20_json_files/t20_wc_player_info.json') as f:
    data = json.load(f)
    
df_players = pd.DataFrame(data)

# %% [markdown]
# ### Data Cleaning

# %%
df_players.head()
# Out:
#                      name     team    battingStyle  \
# 0      Michael van Lingen  Namibia   Left hand Bat
# 1           Divan la Cock  Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton  Namibia   Left hand Bat
# 3           Stephan Baard  Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)  Namibia  Right hand Bat
#
#                  bowlingStyle         playingRole description
# 0             Left arm Medium  Bowling Allrounder
# 1                    Legbreak      Opening Batter
# 2  Right arm Medium, Legbreak              Batter
# 3       Right arm Medium fast              Batter
# 4          Right arm Offbreak          Allrounder

# %%
df_players.duplicated().sum()
# Out:
# 0

# %%
# some player names has duplicated
df_players.drop_duplicates(inplace=True)

# %%
# no need of description column drop it

df_players.drop(columns='description', inplace=True)

# %%
# some player names contains special characters and captain has (c) as abbrevation 

df_players['name'] = df_players['name'].apply(lambda x : x.replace('â€', ''))
df_players['name'] = df_players['name'].apply(lambda x : x.replace('\xa0', ''))
df_players['name'] = df_players['name'].apply(lambda x : x.replace('(c)', ''))

# %% [markdown]
# ## Creating new dataframes
# data in this datasets is not available to fulfill our analysis process. So, we have to create dataframes for batting and bowling performances & add columns to those dataframes respectively.
#
# **Batting Parameters**
# - `Runs Scored` :- Total number of runs scored by the batsman
# - `Innings Batted` :- Total number of innings a batsman got a chance to bat
# - `Innings Dismissed` :- To find the number of innings batsman got out
# - `Batting Average` :-  Average runs scored in an innings
# - `Balls Faced` :- Total number of balls faced by the batsman
# - `Batting Strike Rate` No of runs scored per 100 balls
# - `Batting Position` :- Batting position of a player
# - `Boundary Runs Scored` :- to find the total number of runs scored by hitting fours and sixes
# - `Boundary Percentage Scored` :- Percentage of boundaries scored by the Batsman
# - `Average Balls Faced` :- Average balls faced by the batter in an innings
#
# **Bowling Parameters**
#
# - `Wickets` :- Total number of wickets taken by a bowler
# - `Balls Bowled` :- Total number of balls bowled by the bowler
# - `Runs Conceded` :- Total runs conceded by the bowler
# - `Bowling Economy` :- Average number of runs conceded in an over
# - `Bowling Strike Rate` :- Number of balls bowled per wicket
# - `Bowling Average` :- No. of runs allowed per wicket
# - `Innings Bowled` :- Total number of innings bowled by a bowler
# - `Dot Balls Percentage` :- Percentage of dot balls bowled by a bowler
# - `Boundary Runs Conceded` :- to find the total number of runs conceded by bowlers in boundaries
# - `Boundary Percentage Conceded` :- Percentage of boundaries conceded by the Bowler

# %% [markdown]
# ### Adding batting parameters from df_batting dataframe to batsman df<br>

# %%
batting = df_batting.copy()

# %%
batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        699 non-null    object
#  1   teamInnings  699 non-null    object
#  2   battingPos   699 non-null    int64
#  3   batsmanName  699 non-null    object
#  4   dismissal    699 non-null    object
#  5   runs         699 non-null    object
#  6   balls        699 non-null    object
#  7   4s           699 non-null    object
#  8   6s           699 non-null    object
#  9   SR           699 non-null    object
#  10  dismissed    699 non-null    object
#  11  match_id     699 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 65.7+ KB

# %%
batting.replace('-',0, inplace=True)

# %%
# changing datatype to numeric to perform calculations

batting = batting.astype({'runs':int,
               'balls': int,
               '4s': int,
               '6s': int,
               'SR': float,
               'dismissed' : int})

# %%
batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        699 non-null    object
#  1   teamInnings  699 non-null    object
#  2   battingPos   699 non-null    int64
#  3   batsmanName  699 non-null    object
#  4   dismissal    699 non-null    object
#  5   runs         699 non-null    int32
#  6   balls        699 non-null    int32
#  7   4s           699 non-null    int32
#  8   6s           699 non-null    int32
#  9   SR           699 non-null    float64
#  10  dismissed    699 non-null    int32
#  11  match_id     699 non-null    object
# dtypes: float64(1), int32(5), int64(1), object(5)
# memory usage: 52.0+ KB

# %%
# some batsmanName contains (c) tag that treats same name as two different names 

batting['batsmanName'] = batting['batsmanName'].str.strip('(c)')
batting
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5         Gerhard Erasmus
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#                                dismissal  runs  balls  4s  6s      SR  \
# 0           c Pramod Madushan b Chameera     3      6   0   0   50.00
# 1            c Shanaka b Pramod Madushan     9      9   1   0  100.00
# 2              c â€ Mendis b Karunaratne    20     12   1   2  166.66
# 3        c DM de Silva b Pramod Madushan    26     24   2   0  108.33
# 4           c Gunathilaka b PWH de Silva    20     24   0   0   83.33
# ..                                   ...   ...    ...  ..  ..     ...
# 694        c Iftikhar Ahmed b Haris Rauf    10      9   2   0  111.11
# 695                                         52     49   5   1  106.12
# 696  c Shaheen Shah Afridi b Shadab Khan    20     23   1   0   86.95
# 697                     b Mohammad Wasim    19     13   3   0  146.15
# 698                                          1      1   0   0  100.00
#
#      dismissed     match_id
# 0            1  T20I # 1823
# 1            1  T20I # 1823
# 2            1  T20I # 1823
# 3            1  T20I # 1823
# 4            1  T20I # 1823
# ..         ...          ...
# 694          1  T20I # 1879
# 695          0  T20I # 1879
# 696          1  T20I # 1879
# 697          1  T20I # 1879
# 698          0  T20I # 1879
#
# [699 rows x 12 columns]

# %%
# set index to name to directly assign a column

df_players.set_index('name', inplace=True)

# %%
# create a dataframe which stores all calculated columns related to batting data
batsman = df_players.copy()

# %%
# adding derived columns to dataframe

batsman['runsScored'] = batting.groupby('batsmanName')['runs'].sum()
batsman['inningsBatted'] = batting.groupby('batsmanName')['match'].count()
batsman['inningsDismissed'] = batting.groupby('batsmanName')['dismissed'].sum()
batsman['ballsFaced'] = batting.groupby('batsmanName')['balls'].sum()
batsman['battingPos'] = batting.groupby('batsmanName')['battingPos'].mean().round()
batsman['boundaryRuns'] = batting.groupby('batsmanName')['4s'].sum()*4 + batting.groupby('batsmanName')['6s'].sum()*6
batsman['boundary%'] = round(batsman['boundaryRuns'] / batsman['runsScored'] * 100, 2)
batsman['battingAvg'] = round(batsman['runsScored'] / batsman['inningsDismissed'].apply(lambda x: x if x!=0 else 1) , 2)
batsman['avgBallsFaced'] = round(batsman['ballsFaced']/batsman['inningsBatted'], 2)
batsman['battingS/R'] = round(batsman['runsScored'] / batsman['ballsFaced'] * 100, 2)

# %%
batsman.sample(20)
# Out:
#                           team    battingStyle            bowlingStyle  \
# name
# David Miller      South Africa   Left hand Bat      Right arm Offbreak
# Soumya Sarkar       Bangladesh   Left hand Bat   Right arm Medium fast
# Milton Shumba         Zimbabwe   Left hand Bat  Slow Left arm Orthodox
# Aayan Afzal Khan        U.A.E.  Right hand Bat  Slow Left arm Orthodox
# KL Rahul                 India  Right hand Bat
# Regis Chakabva        Zimbabwe  Right hand Bat      Right arm Offbreak
# Andy Balbirnie         Ireland  Right hand Bat      Right arm Offbreak
# Glenn Phillips     New Zealand  Right hand Bat      Right arm Offbreak
# Zawar Farid             U.A.E.  Right hand Bat        Right arm Medium
# Harry Tector           Ireland  Right hand Bat      Right arm Offbreak
# Iftikhar Ahmed        Pakistan  Right hand Bat      Right arm Offbreak
# Fareed Ahmad       Afghanistan   Left hand Bat    Left arm Fast medium
# Brad Evans            Zimbabwe  Right hand Bat          Right arm Fast
# Sam Curran             England   Left hand Bat    Left arm Medium fast
# Trent Boult        New Zealand  Right hand Bat    Left arm Fast medium
# Marcus Stoinis       Australia  Right hand Bat        Right arm Medium
# Craig Ervine          Zimbabwe   Left hand Bat      Right arm Offbreak
# Jason Holder       West Indies  Right hand Bat   Right arm Medium fast
# Gulbadin Naib      Afghanistan  Right hand Bat   Right arm Medium fast
# Vikramjit Singh    Netherlands   Left hand Bat   Right arm Medium fast
#
#                           playingRole  runsScored  inningsBatted  \
# name
# David Miller      Middle order Batter        78.0            3.0
# Soumya Sarkar     Middle order Batter        49.0            4.0
# Milton Shumba        Top order Batter        65.0            7.0
# Aayan Afzal Khan   Bowling Allrounder        24.0            2.0
# KL Rahul               Opening Batter       128.0            6.0
# Regis Chakabva    Wicketkeeper Batter        45.0            8.0
# Andy Balbirnie                 Batter       153.0            7.0
# Glenn Phillips    Wicketkeeper Batter       201.0            5.0
# Zawar Farid                    Bowler         2.0            1.0
# Harry Tector      Middle order Batter        68.0            6.0
# Iftikhar Ahmed    Middle order Batter       114.0            7.0
# Fareed Ahmad                   Bowler         2.0            1.0
# Brad Evans                 Allrounder        21.0            2.0
# Sam Curran                 Allrounder        12.0            2.0
# Trent Boult                    Bowler         NaN            NaN
# Marcus Stoinis     Batting Allrounder       126.0            4.0
# Craig Ervine      Middle order Batter       112.0            7.0
# Jason Holder       Bowling Allrounder        42.0            2.0
# Gulbadin Naib      Batting Allrounder        51.0            2.0
# Vikramjit Singh        Opening Batter        57.0            5.0
#
#                   inningsDismissed  ballsFaced  battingPos  boundaryRuns  \
# name
# David Miller                   1.0        67.0         5.0          38.0
# Soumya Sarkar                  4.0        39.0         2.0          30.0
# Milton Shumba                  6.0        82.0         5.0          20.0
# Aayan Afzal Khan               2.0        28.0         8.0           4.0
# KL Rahul                       6.0       106.0         1.0          80.0
# Regis Chakabva                 8.0        64.0         3.0          26.0
# Andy Balbirnie                 7.0       123.0         2.0          94.0
# Glenn Phillips                 5.0       127.0         4.0         124.0
# Zawar Farid                    1.0         4.0         5.0           0.0
# Harry Tector                   6.0        75.0         4.0          22.0
# Iftikhar Ahmed                 5.0        93.0         5.0          60.0
# Fareed Ahmad                   0.0         4.0        10.0           0.0
# Brad Evans                     2.0        17.0         8.0           6.0
# Sam Curran                     1.0        14.0         7.0           6.0
# Trent Boult                    NaN         NaN         NaN           NaN
# Marcus Stoinis                 3.0        78.0         5.0          82.0
# Craig Ervine                   7.0       125.0         2.0          52.0
# Jason Holder                   2.0        36.0         7.0          22.0
# Gulbadin Naib                  2.0        37.0         4.0          24.0
# Vikramjit Singh                5.0        62.0         1.0          32.0
#
#                   boundary%  battingAvg  avgBallsFaced  battingS/R
# name
# David Miller          48.72       78.00          22.33      116.42
# Soumya Sarkar         61.22       12.25           9.75      125.64
# Milton Shumba         30.77       10.83          11.71       79.27
# Aayan Afzal Khan      16.67       12.00          14.00       85.71
# KL Rahul              62.50       21.33          17.67      120.75
# Regis Chakabva        57.78        5.62           8.00       70.31
# Andy Balbirnie        61.44       21.86          17.57      124.39
# Glenn Phillips        61.69       40.20          25.40      158.27
# Zawar Farid            0.00        2.00           4.00       50.00
# Harry Tector          32.35       11.33          12.50       90.67
# Iftikhar Ahmed        52.63       22.80          13.29      122.58
# Fareed Ahmad           0.00        2.00           4.00       50.00
# Brad Evans            28.57       10.50           8.50      123.53
# Sam Curran            50.00       12.00           7.00       85.71
# Trent Boult             NaN         NaN            NaN         NaN
# Marcus Stoinis        65.08       42.00          19.50      161.54
# Craig Ervine          46.43       16.00          17.86       89.60
# Jason Holder          52.38       21.00          18.00      116.67
# Gulbadin Naib         47.06       25.50          18.50      137.84
# Vikramjit Singh       56.14       11.40          12.40       91.94

# %% [markdown]
# ### Adding bowling parameters from df_bowling dataframe to bowler df<br>

# %%
bowling = df_bowling.copy()

# %%
bowling.sample(2)
# Out:
#                         match bowlingTeam       bowlerName overs maiden runs  \
# 397    New Zealand Vs Ireland     Ireland  George Dockrell     2      0   18
# 409  Australia Vs Afghanistan   Australia   Josh Hazlewood     4      0   33
#
#     wickets economy  0s 4s 6s wides noBalls     match_id
# 397       0    9.00   4  2  0     2       0  T20I # 1862
# 409       2    8.25  13  2  3     0       0  T20I # 1864

# %%
bowling = bowling.astype({'overs': float})

# %%
# over columns contains some float values that is not suitable for further calcutation
# so, we have to convert it into no. of balls

bowling['noBalls'] = np.floor(bowling['overs'])*6 + bowling['overs']%1*10

# %%
bowling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        500 non-null    object
#  1   bowlingTeam  500 non-null    object
#  2   bowlerName   500 non-null    object
#  3   overs        500 non-null    float64
#  4   maiden       500 non-null    object
#  5   runs         500 non-null    object
#  6   wickets      500 non-null    object
#  7   economy      500 non-null    object
#  8   0s           500 non-null    object
#  9   4s           500 non-null    object
#  10  6s           500 non-null    object
#  11  wides        500 non-null    object
#  12  noBalls      500 non-null    float64
#  13  match_id     500 non-null    object
# dtypes: float64(2), object(12)
# memory usage: 54.8+ KB

# %%
bowling = bowling.astype({
                  'maiden': int, 
                  'runs': int,
                  'wickets': int,
                  'economy': float,
                  '0s': int,
                  '4s': int, 
                  '6s': int,
                  'wides': int,
                  'noBalls': int
})

# %%
# create a new dataframe of bowler which consists of all calculated columns of bowlers

bowler = df_players.copy()

# %%
bowling
# Out:
#                     match bowlingTeam                  bowlerName  overs  \
# 0    Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana    4.0
# 1    Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera    4.0
# 2    Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan    4.0
# 3    Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne    4.0
# 4    Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva    4.0
# ..                    ...         ...                         ...    ...
# 495   Pakistan Vs England    Pakistan                 Naseem Shah    4.0
# 496   Pakistan Vs England    Pakistan                  Haris Rauf    4.0
# 497   Pakistan Vs England    Pakistan                 Shadab Khan    4.0
# 498   Pakistan Vs England    Pakistan              Mohammad Wasim    4.0
# 499   Pakistan Vs England    Pakistan              Iftikhar Ahmed    0.5
#
#      maiden  runs  wickets  economy  0s  4s  6s  wides  noBalls     match_id
# 0         0    23        1     5.75   7   0   0      2       24  T20I # 1823
# 1         0    39        1     9.75   6   3   1      2       24  T20I # 1823
# 2         0    37        2     9.25   6   3   1      0       24  T20I # 1823
# 3         0    36        1     9.00   7   3   1      1       24  T20I # 1823
# 4         0    27        1     6.75   8   1   1      0       24  T20I # 1823
# ..      ...   ...      ...      ...  ..  ..  ..    ...      ...          ...
# 495       0    30        0     7.50  15   3   1      1       24  T20I # 1879
# 496       0    23        2     5.75  13   3   0      1       24  T20I # 1879
# 497       0    20        1     5.00  10   1   0      0       24  T20I # 1879
# 498       0    38        1     9.50   5   5   0      2       24  T20I # 1879
# 499       0    13        0    15.60   0   1   1      0        5  T20I # 1879
#
# [500 rows x 14 columns]

# %%
bowler['wickets'] = bowling.groupby('bowlerName')['wickets'].sum()
bowler['ballsBowled'] = bowling.groupby('bowlerName')['noBalls'].sum()
bowler['runsConceded'] = bowling.groupby('bowlerName')['runs'].sum()
bowler['bowlerEconomy'] = round(bowler['runsConceded']/bowler['ballsBowled']*6, 2)
# if wickets = 0 then it gives infinity, so apply lambda function
bowler['bowlingS/R'] = round(bowler['ballsBowled']/bowler['wickets'].apply(lambda x: x if x!=0 else 1), 2)
bowler['bowlingAvg'] = round(bowler['runsConceded']/bowler['wickets'].apply(lambda x: x if x!=0 else 1), 2)
bowler['inningsBowled'] = bowling.groupby('bowlerName')['wickets'].count()
bowler['dotBalls%'] = round(bowling.groupby('bowlerName')['0s'].sum()/bowling.groupby('bowlerName')['noBalls'].sum()*100, 2)
bowler['boundaryRunsConceded'] = bowling.groupby('bowlerName')['4s'].sum() +  bowling.groupby('bowlerName')['6s'].sum()
bowler['boundaryConceded%'] = round(bowler['boundaryRunsConceded']/bowler['runsConceded']*100, 2)

# %%
bowler.sample(10)
# Out:
#                           team    battingStyle            bowlingStyle  \
# name
# Richard Ngarava       Zimbabwe   Left hand Bat    Left arm Fast medium
# Pramod Madushan      Sri Lanka  Right hand Bat   Right arm Medium fast
# Stephan Myburgh    Netherlands   Left hand Bat      Right arm Offbreak
# Steven Smith         Australia  Right hand Bat         Legbreak Googly
# Mitchell Santner   New Zealand   Left hand Bat  Slow Left arm Orthodox
# Nicholas Pooran    West Indies   Left hand Bat      Right arm Offbreak
# Gerhard Erasmus        Namibia  Right hand Bat      Right arm Offbreak
# Ahmed Raza              U.A.E.  Right hand Bat  Slow Left arm Orthodox
# Nasum Ahmed         Bangladesh   Left hand Bat  Slow Left arm Orthodox
# Lungi Ngidi       South Africa  Right hand Bat   Right arm Fast medium
#
#                           playingRole  wickets  ballsBowled  runsConceded  \
# name
# Richard Ngarava                Bowler      9.0        168.0         197.0
# Pramod Madushan                Bowler      3.0         60.0          75.0
# Stephan Myburgh        Opening Batter      NaN          NaN           NaN
# Steven Smith      Middle order Batter      NaN          NaN           NaN
# Mitchell Santner   Bowling Allrounder      9.0        120.0         129.0
# Nicholas Pooran   Wicketkeeper Batter      NaN          NaN           NaN
# Gerhard Erasmus            Allrounder      0.0         24.0          21.0
# Ahmed Raza                     Bowler      0.0          6.0           9.0
# Nasum Ahmed                    Bowler      1.0         24.0          14.0
# Lungi Ngidi                    Bowler      7.0         78.0         116.0
#
#                   bowlerEconomy  bowlingS/R  bowlingAvg  inningsBowled  \
# name
# Richard Ngarava            7.04       18.67       21.89            8.0
# Pramod Madushan            7.50       20.00       25.00            3.0
# Stephan Myburgh             NaN         NaN         NaN            NaN
# Steven Smith                NaN         NaN         NaN            NaN
# Mitchell Santner           6.45       13.33       14.33            5.0
# Nicholas Pooran             NaN         NaN         NaN            NaN
# Gerhard Erasmus            5.25       24.00       21.00            2.0
# Ahmed Raza                 9.00        6.00        9.00            1.0
# Nasum Ahmed                3.50       24.00       14.00            1.0
# Lungi Ngidi                8.92       11.14       16.57            4.0
#
#                   dotBalls%  boundaryRunsConceded  boundaryConceded%
# name
# Richard Ngarava       52.98                  26.0              13.20
# Pramod Madushan       41.67                   9.0              12.00
# Stephan Myburgh         NaN                   NaN                NaN
# Steven Smith            NaN                   NaN                NaN
# Mitchell Santner      40.83                  14.0              10.85
# Nicholas Pooran         NaN                   NaN                NaN
# Gerhard Erasmus       37.50                   1.0               4.76
# Ahmed Raza            16.67                   1.0              11.11
# Nasum Ahmed           54.17                   0.0               0.00
# Lungi Ngidi           38.46                  16.0              13.79

# %%
# df contains some nan values i.e. records of batsman who didn't bowl, fill those nan values with 0
bowler.fillna(0, inplace=True)

# %%
# changing datatype

bowler[['wickets', 'ballsBowled', 'runsConceded', 'inningsBowled', 'boundaryRunsConceded']] = bowler[['wickets', 'ballsBowled', 'runsConceded', 'inningsBowled', 'boundaryRunsConceded']].astype(int)

# %%
bowler
# Out:
#                                 team    battingStyle  \
# name
# Michael van Lingen           Namibia   Left hand Bat
# Divan la Cock                Namibia  Right hand Bat
# Jan Nicol Loftie-Eaton       Namibia   Left hand Bat
# Stephan Baard                Namibia  Right hand Bat
# Gerhard Erasmus              Namibia  Right hand Bat
# ...                              ...             ...
# Wellington Masakadza        Zimbabwe   Left hand Bat
# Tabraiz Shamsi          South Africa  Right hand Bat
# Phil Salt                    England  Right hand Bat
# Chris Jordan                 England  Right hand Bat
# Mehidy Hasan Miraz        Bangladesh  Right hand Bat
#
#                                       bowlingStyle          playingRole  \
# name
# Michael van Lingen                 Left arm Medium   Bowling Allrounder
# Divan la Cock                             Legbreak       Opening Batter
# Jan Nicol Loftie-Eaton  Right arm Medium, Legbreak               Batter
# Stephan Baard                Right arm Medium fast               Batter
# Gerhard Erasmus                 Right arm Offbreak           Allrounder
# ...                                            ...                  ...
# Wellington Masakadza        Slow Left arm Orthodox               Bowler
# Tabraiz Shamsi                 Left arm Wrist spin               Bowler
# Phil Salt                       Right arm Offbreak  Wicketkeeper Batter
# Chris Jordan                 Right arm Fast medium               Bowler
# Mehidy Hasan Miraz              Right arm Offbreak           Allrounder
#
#                         wickets  ballsBowled  runsConceded  bowlerEconomy  \
# name
# Michael van Lingen            0            0             0           0.00
# Divan la Cock                 0            0             0           0.00
# Jan Nicol Loftie-Eaton        0            6             8           8.00
# Stephan Baard                 0            0             0           0.00
# Gerhard Erasmus               0           24            21           5.25
# ...                         ...          ...           ...            ...
# Wellington Masakadza          0           12            12           6.00
# Tabraiz Shamsi                4           48            56           7.00
# Phil Salt                     0            0             0           0.00
# Chris Jordan                  5           48            70           8.75
# Mehidy Hasan Miraz            0           18            32          10.67
#
#                         bowlingS/R  bowlingAvg  inningsBowled  dotBalls%  \
# name
# Michael van Lingen             0.0         0.0              0       0.00
# Divan la Cock                  0.0         0.0              0       0.00
# Jan Nicol Loftie-Eaton         6.0         8.0              1      33.33
# Stephan Baard                  0.0         0.0              0       0.00
# Gerhard Erasmus               24.0        21.0              2      37.50
# ...                            ...         ...            ...        ...
# Wellington Masakadza          12.0        12.0              1      41.67
# Tabraiz Shamsi                12.0        14.0              2      41.67
# Phil Salt                      0.0         0.0              0       0.00
# Chris Jordan                   9.6        14.0              2      35.42
# Mehidy Hasan Miraz            18.0        32.0              1      22.22
#
#                         boundaryRunsConceded  boundaryConceded%
# name
# Michael van Lingen                         0               0.00
# Divan la Cock                              0               0.00
# Jan Nicol Loftie-Eaton                     1              12.50
# Stephan Baard                              0               0.00
# Gerhard Erasmus                            1               4.76
# ...                                      ...                ...
# Wellington Masakadza                       1               8.33
# Tabraiz Shamsi                             5               8.93
# Phil Salt                                  0               0.00
# Chris Jordan                               9              12.86
# Mehidy Hasan Miraz                         4              12.50
#
# [198 rows x 14 columns]

# %% [markdown]
# ### Selecting players for each playing role
# - below are some criteria or requirement a player must have to be selected for a playing role in a team.
# - select players according to that and create a dataframe of each type

# %% [markdown]
# #### `Player role` , `No. of players` for that role and `parameters and eligibility criteria` to be selected is predefined to select the best ones
#
# **Openers (2)**
# - Batting Average > 30
# - Strike Rate > 140
# - Innings Batted > 3
# - Boundary %  > 50
# - Batting Position < 4
#
# **Middle Orders (2)**
# - Batting Average > 40
# - Strike Rate > 125
# - Innings Batted > 3
# - Avg. Balls Faced > 20
# - Batting Position > 2
#
# **Batting All-rounders (2)**
# - Batting Average > 25
# - Strike Rate > 130
# - Innings Batted > 3
# - Avg. Balls Faced > 12
# - Batting Position > 4
# - Innings Bowled > 1
#
# **Bowling All-rounders (2)**
# - Batting Average > 15
# - Strike Rate > 140
# - Innings Batted > 2
# - Order in which the batter played > 4
# - Innings Bowled > 2
# - Bowling Economy < 7
# - Bowling Strike Rate < 20
#
# **Fast Bowlers (3)**
# - Innings Bowled > 4
# - Bowling Economy < 7
# - Bowling Strike Rate < 16
# - Bowling Average < 20
# - Dot Ball % > 40

# %%
# selecting openers that satisfies the required criteria and parameters

conditions = ((batsman['battingAvg'] > 30) &
              (batsman['battingS/R']>140) &
              (batsman['inningsBatted']>3) &
              (batsman['boundary%']>50) &
              (batsman['battingPos']<4))
opener = batsman[conditions]

# %%
# selecting middle order players that satisfies the required criteria and parameters

conditions = ((batsman['battingAvg'] > 40) &
              (batsman['battingS/R']>125) &
              (batsman['inningsBatted']>3) &
              (batsman['avgBallsFaced']>20) &
              (batsman['battingPos']>2))
middle_order = batsman[conditions]

# %%
# selecting batting_all_rounder players that satisfies the required criteria and parameters

all_rounder = batsman.reset_index().merge(bowler.reset_index(), how='inner').set_index('name')
# here it requires conditions of batsman and bowler so merge it to a new dataframe

conditions = ((all_rounder['battingAvg'] > 25) &
              (all_rounder['battingS/R']>130) &
              (all_rounder['inningsBatted']>3) &
              (all_rounder['avgBallsFaced']>12) &
              (all_rounder['battingPos']>3) &
              (all_rounder['inningsBowled']>1))
bat_all_rounder = all_rounder[conditions]

# %%
# selecting bowling all rounder players that satisfies the required criteria and parameters

all_rounder = batsman.reset_index().merge(bowler.reset_index(), how='inner').set_index('name')
# here it requires conditions of batsman and bowler so merge it to a new dataframe

conditions = ((all_rounder['battingAvg'] > 15) &
              (all_rounder['battingS/R']>140) &
              (all_rounder['inningsBatted']>2) &
              (all_rounder['battingPos']>4) &
              (all_rounder['inningsBowled']>2) &
              (all_rounder['bowlerEconomy']<7) &
              (all_rounder['bowlingS/R']<20))
bowl_all_rounder = all_rounder[conditions]

# %%
# selecting bowlers that satisfies the required criteria and parameters

conditions = ((bowler['inningsBowled'] > 4) &
              (bowler['bowlerEconomy']<7) &
              (bowler['bowlingS/R']<16) &
              (bowler['bowlingAvg']<20) & 
              (bowler['dotBalls%']>40))# &
              # (bowler['bowlingStyle'].str.contains('fast', case=False))) # this condition is just selecting fast bowlers
faster = bowler[conditions]

# %%
faster
# Out:
#                              team    battingStyle            bowlingStyle  \
# name
# Sam Curran                England   Left hand Bat    Left arm Medium fast
# Shaheen Shah Afridi      Pakistan   Left hand Bat           Left arm Fast
# Anrich Nortje        South Africa  Right hand Bat          Right arm Fast
# Tim Southee           New Zealand  Right hand Bat   Right arm Medium fast
# Mitchell Santner      New Zealand   Left hand Bat  Slow Left arm Orthodox
#
#                             playingRole  wickets  ballsBowled  runsConceded  \
# name
# Sam Curran                   Allrounder       13          136           148
# Shaheen Shah Afridi              Bowler       11          151           155
# Anrich Nortje                    Bowler       11          105            94
# Tim Southee                      Bowler        7          104           114
# Mitchell Santner     Bowling Allrounder        9          120           129
#
#                      bowlerEconomy  bowlingS/R  bowlingAvg  inningsBowled  \
# name
# Sam Curran                    6.53       10.46       11.38              6
# Shaheen Shah Afridi           6.16       13.73       14.09              7
# Anrich Nortje                 5.37        9.55        8.55              5
# Tim Southee                   6.58       14.86       16.29              5
# Mitchell Santner              6.45       13.33       14.33              5
#
#                      dotBalls%  boundaryRunsConceded  boundaryConceded%
# name
# Sam Curran               48.53                    14               9.46
# Shaheen Shah Afridi      46.36                    16              10.32
# Anrich Nortje            55.24                     8               8.51
# Tim Southee              50.00                    14              12.28
# Mitchell Santner         40.83                    14              10.85

# %% [markdown]
# #  Step 3 :- EDA (Exploratory Data Analysis)

# %% [markdown]
# ### 1. Opener Batsman

# %%
opener # we choose openers by analyzing their performances
# Out:
#                          team    battingStyle        bowlingStyle  \
# name
# Kusal Mendis        Sri Lanka  Right hand Bat            Legbreak
# Jos Buttler           England  Right hand Bat
# Alex Hales            England  Right hand Bat    Right arm Medium
# Quinton de Kock  South Africa   Left hand Bat
# Rilee Rossouw    South Africa   Left hand Bat  Right arm Offbreak
#
#                          playingRole  runsScored  inningsBatted  \
# name
# Kusal Mendis     Wicketkeeper Batter       223.0            8.0
# Jos Buttler      Wicketkeeper Batter       225.0            6.0
# Alex Hales            Opening Batter       212.0            6.0
# Quinton de Kock  Wicketkeeper Batter       124.0            5.0
# Rilee Rossouw       Top order Batter       141.0            4.0
#
#                  inningsDismissed  ballsFaced  battingPos  boundaryRuns  \
# name
# Kusal Mendis                  7.0       156.0         2.0         128.0
# Jos Buttler                   5.0       156.0         1.0         138.0
# Alex Hales                    5.0       144.0         2.0         136.0
# Quinton de Kock               4.0        77.0         1.0          94.0
# Rilee Rossouw                 4.0        83.0         3.0          90.0
#
#                  boundary%  battingAvg  avgBallsFaced  battingS/R
# name
# Kusal Mendis         57.40       31.86          19.50      142.95
# Jos Buttler          61.33       45.00          26.00      144.23
# Alex Hales           64.15       42.40          24.00      147.22
# Quinton de Kock      75.81       31.00          15.40      161.04
# Rilee Rossouw        63.83       35.25          20.75      169.88

# %%
mpl.rcParams['lines.markersize'] = 50             # --> set markersize here
plt.figure(figsize=(16,8))
sns.scatterplot(data=opener, x='battingAvg', y='battingS/R', hue='battingStyle', size='avgBallsFaced', s=100)
for i in range(opener.shape[0]):
    plt.text(x=opener.battingAvg.values[i], y=opener['battingS/R'].values[i], s=opener.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((30,170), (46, 140))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %% [markdown]
# - from the above chart we have three players to be selected as openers & we have to select 2 of them.
# - from that we'll go for the combination of left and right for that we choose
# - `Jos Buttler` who stays in the field consistently and
# - `Rilee Rossouw` plays a major role in power hitting to achieve higher score

# %%
# same plot using plotly express library
# px.scatter(opener, x='battingAvg', y='battingS/R',size='boundary%', color='battingStyle', text=opener.index)

# %% [markdown]
# ### 2. Middle_order batsman

# %%
middle_order
# Out:
#                          team    battingStyle  \
# name
# Lorcan Tucker         Ireland  Right hand Bat
# Virat Kohli             India  Right hand Bat
# Suryakumar Yadav        India  Right hand Bat
# Glenn Phillips    New Zealand  Right hand Bat
# Daryl Mitchell    New Zealand  Right hand Bat
#
#                                           bowlingStyle          playingRole  \
# name
# Lorcan Tucker                                           Wicketkeeper Batter
# Virat Kohli                           Right arm Medium     Top order Batter
# Suryakumar Yadav  Right arm Medium, Right arm Offbreak               Batter
# Glenn Phillips                      Right arm Offbreak  Wicketkeeper Batter
# Daryl Mitchell                        Right arm Medium           Allrounder
#
#                   runsScored  inningsBatted  inningsDismissed  ballsFaced  \
# name
# Lorcan Tucker          204.0            7.0               5.0       163.0
# Virat Kohli            296.0            6.0               3.0       217.0
# Suryakumar Yadav       239.0            6.0               4.0       126.0
# Glenn Phillips         201.0            5.0               5.0       127.0
# Daryl Mitchell         109.0            4.0               2.0        85.0
#
#                   battingPos  boundaryRuns  boundary%  battingAvg  \
# name
# Lorcan Tucker            3.0         100.0      49.02       40.80
# Virat Kohli              3.0         148.0      50.00       98.67
# Suryakumar Yadav         4.0         158.0      66.11       59.75
# Glenn Phillips           4.0         124.0      61.69       40.20
# Daryl Mitchell           5.0          26.0      23.85       54.50
#
#                   avgBallsFaced  battingS/R
# name
# Lorcan Tucker             23.29      125.15
# Virat Kohli               36.17      136.41
# Suryakumar Yadav          21.00      189.68
# Glenn Phillips            25.40      158.27
# Daryl Mitchell            21.25      128.24

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=middle_order, x='battingAvg', y='battingS/R', hue='battingStyle', size='avgBallsFaced', s=10)
for i in range(middle_order.shape[0]):
    plt.text(x=middle_order.battingAvg.values[i], y=middle_order['battingS/R'].values[i], s=middle_order.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((40,190), (100, 120))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %% [markdown]
# - for middle order we have to choose 2 batsman and that will be surely qualified for that role with their performance across the tournament.
# - their batting average consistency and a power hitting abilities made them best over other players.
# - `Virat Kohli` and  `Suryakumar Yadav`

# %% [markdown]
# ### 3. Batting All_rounder

# %%
bat_all_rounder
# Out:
#                      team    battingStyle           bowlingStyle  \
# name
# Glenn Maxwell   Australia  Right hand Bat     Right arm Offbreak
# Marcus Stoinis  Australia  Right hand Bat       Right arm Medium
# Sikandar Raza    Zimbabwe  Right hand Bat     Right arm Offbreak
# Curtis Campher    Ireland  Right hand Bat  Right arm Medium fast
# Hardik Pandya       India  Right hand Bat  Right arm Medium fast
#
#                        playingRole  runsScored  inningsBatted  \
# name
# Glenn Maxwell   Batting Allrounder       118.0            4.0
# Marcus Stoinis  Batting Allrounder       126.0            4.0
# Sikandar Raza   Batting Allrounder       219.0            8.0
# Curtis Campher          Allrounder       126.0            6.0
# Hardik Pandya           Allrounder       128.0            5.0
#
#                 inningsDismissed  ballsFaced  battingPos  boundaryRuns  ...  \
# name                                                                    ...
# Glenn Maxwell                3.0        73.0         4.0          80.0  ...
# Marcus Stoinis               3.0        78.0         5.0          82.0  ...
# Sikandar Raza                8.0       148.0         5.0         130.0  ...
# Curtis Campher               5.0        77.0         5.0          60.0  ...
# Hardik Pandya                5.0        97.0         6.0          70.0  ...
#
#                 wickets  ballsBowled  runsConceded  bowlerEconomy  bowlingS/R  \
# name
# Glenn Maxwell         3           19            19           6.00        6.33
# Marcus Stoinis        1           54            87           9.67       54.00
# Sikandar Raza        10          144           156           6.50       14.40
# Curtis Campher        2           48            74           9.25       24.00
# Hardik Pandya         8          108           146           8.11       13.50
#
#                 bowlingAvg  inningsBowled  dotBalls%  boundaryRunsConceded  \
# name
# Glenn Maxwell         6.33              2      42.11                     2
# Marcus Stoinis       87.00              4      14.81                     7
# Sikandar Raza        15.60              8      31.94                     9
# Curtis Campher       37.00              4      35.42                    11
# Hardik Pandya        18.25              6      38.89                    15
#
#                 boundaryConceded%
# name
# Glenn Maxwell               10.53
# Marcus Stoinis               8.05
# Sikandar Raza                5.77
# Curtis Campher              14.86
# Hardik Pandya               10.27
#
# [5 rows x 24 columns]

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=bat_all_rounder, x='battingAvg', y='battingS/R', hue='battingStyle', size='boundary%', s=10)
for i in range(bat_all_rounder.shape[0]):
    plt.text(x=bat_all_rounder.battingAvg.values[i], y=bat_all_rounder['battingS/R'].values[i], s=bat_all_rounder.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((25,170), (45, 130))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=bat_all_rounder, x='bowlerEconomy', y='bowlingS/R', hue='bowlingStyle', size='dotBalls%', s=10)
for i in range(bat_all_rounder.shape[0]):
    plt.text(x=bat_all_rounder.bowlerEconomy.values[i], y=bat_all_rounder['bowlingS/R'].values[i], s=bat_all_rounder.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((6,55),(10,5))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %% [markdown]
# - as batting all rounder we will choose `Glenn Maxwell` and `Marcus Stoinis` for his batting performance
# - although `Marcus Stoinis` has not well contribution to bowling
# - we have `Sikandar Raza` as option instead of him for spin and `Hardik Pandya` for fast both of them have boundary hitting abilities

# %% [markdown]
# ### 4. Bowling All_rounder

# %%
bowl_all_rounder
# Out:
#                          team    battingStyle            bowlingStyle  \
# name
# Sikandar Raza        Zimbabwe  Right hand Bat      Right arm Offbreak
# Rashid Khan       Afghanistan  Right hand Bat         Legbreak Googly
# Shadab Khan          Pakistan  Right hand Bat                Legbreak
# Mitchell Santner  New Zealand   Left hand Bat  Slow Left arm Orthodox
#
#                          playingRole  runsScored  inningsBatted  \
# name
# Sikandar Raza     Batting Allrounder       219.0            8.0
# Rashid Khan       Bowling Allrounder        57.0            3.0
# Shadab Khan               Allrounder        98.0            6.0
# Mitchell Santner  Bowling Allrounder        27.0            3.0
#
#                   inningsDismissed  ballsFaced  battingPos  boundaryRuns  ...  \
# name                                                                      ...
# Sikandar Raza                  8.0       148.0         5.0         130.0  ...
# Rashid Khan                    2.0        32.0         8.0          40.0  ...
# Shadab Khan                    4.0        58.0         6.0          58.0  ...
# Mitchell Santner               1.0        16.0         7.0          12.0  ...
#
#                   wickets  ballsBowled  runsConceded  bowlerEconomy  \
# name
# Sikandar Raza          10          144           156           6.50
# Rashid Khan             4           72            77           6.42
# Shadab Khan            11          156           165           6.35
# Mitchell Santner        9          120           129           6.45
#
#                   bowlingS/R  bowlingAvg  inningsBowled  dotBalls%  \
# name
# Sikandar Raza          14.40       15.60              8      31.94
# Rashid Khan            18.00       19.25              3      40.28
# Shadab Khan            14.18       15.00              7      37.82
# Mitchell Santner       13.33       14.33              5      40.83
#
#                   boundaryRunsConceded  boundaryConceded%
# name
# Sikandar Raza                        9               5.77
# Rashid Khan                          6               7.79
# Shadab Khan                         15               9.09
# Mitchell Santner                    14              10.85
#
# [4 rows x 24 columns]

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=bowl_all_rounder, x='battingAvg', y='battingS/R', hue='battingStyle', size='boundary%', s=10)
for i in range(bowl_all_rounder.shape[0]):
    plt.text(x=bowl_all_rounder.battingAvg.values[i], y=bowl_all_rounder['battingS/R'].values[i], s=bowl_all_rounder.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((24,180), (29, 140))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=bowl_all_rounder, x='bowlerEconomy', y='bowlingS/R', hue='bowlingStyle', size='dotBalls%', s=10)
for i in range(bowl_all_rounder.shape[0]):
    plt.text(x=bowl_all_rounder.bowlerEconomy.values[i], y=bowl_all_rounder['bowlingS/R'].values[i], s=bowl_all_rounder.index[i])
plt.axline((6.35,19),(6.5,12))
plt.title('Batting S/R vs Batting Avg.')
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %% [markdown]
# - for batting performance `Mitchell Santner` and `Rashid Khan` well qualified
# - for bowling performance `Shadab Khan`, `Mitchell Santner` and `Sikandar Raza` qualifies
# - as bowling all rounder we will choose `Shadab Khan` and `Mitchell Santner`who well performs with his bat also

# %% [markdown]
# ### 5. Fast bowlers

# %%
faster
# Out:
#                              team    battingStyle            bowlingStyle  \
# name
# Sam Curran                England   Left hand Bat    Left arm Medium fast
# Shaheen Shah Afridi      Pakistan   Left hand Bat           Left arm Fast
# Anrich Nortje        South Africa  Right hand Bat          Right arm Fast
# Tim Southee           New Zealand  Right hand Bat   Right arm Medium fast
# Mitchell Santner      New Zealand   Left hand Bat  Slow Left arm Orthodox
#
#                             playingRole  wickets  ballsBowled  runsConceded  \
# name
# Sam Curran                   Allrounder       13          136           148
# Shaheen Shah Afridi              Bowler       11          151           155
# Anrich Nortje                    Bowler       11          105            94
# Tim Southee                      Bowler        7          104           114
# Mitchell Santner     Bowling Allrounder        9          120           129
#
#                      bowlerEconomy  bowlingS/R  bowlingAvg  inningsBowled  \
# name
# Sam Curran                    6.53       10.46       11.38              6
# Shaheen Shah Afridi           6.16       13.73       14.09              7
# Anrich Nortje                 5.37        9.55        8.55              5
# Tim Southee                   6.58       14.86       16.29              5
# Mitchell Santner              6.45       13.33       14.33              5
#
#                      dotBalls%  boundaryRunsConceded  boundaryConceded%
# name
# Sam Curran               48.53                    14               9.46
# Shaheen Shah Afridi      46.36                    16              10.32
# Anrich Nortje            55.24                     8               8.51
# Tim Southee              50.00                    14              12.28
# Mitchell Santner         40.83                    14              10.85

# %%
mpl.rcParams['lines.markersize'] = 50             # <---- set markersize here
plt.figure(figsize=(16, 8))
sns.scatterplot(data=faster, x='bowlerEconomy', y='bowlingS/R', hue='bowlingStyle', size='dotBalls%', s=10)
for i in range(faster.shape[0]):
    plt.text(x=faster.bowlerEconomy.values[i], y=faster['bowlingS/R'].values[i], s=faster.index[i])
plt.title('Batting S/R vs Batting Avg.')
plt.axline((5.4,15), (6.6, 10))
plt.legend(markerscale=0.2)
plt.grid()
plt.show()

# %% [markdown]
# - here every bowler has almost same in performance but we have to choose only 3 of them.
# - so, we will go for `Anrich Nortje` and `Sam Curran` for their wicket taking ability.
# - and third bowler as `Shaheen Shah Afridi`.

# %% [markdown]
# in terms of bowling we have `Anrich Nortje` for his best performance and `Shaheen Shah Afridi` and `Sam Curran`

# %% [markdown]
# #  Step 4 :- Drawing Conclusions

# %% [markdown]
# ### Now Analysing whole team performance

# %%
def build_team(players):
    
    """Take list of players and after applying some functions over it returns it as dataframe having all information of team"""
    
    parameters = all_rounder[['battingStyle', 'bowlingStyle', 'battingAvg', 'battingS/R','boundary%', 'avgBallsFaced', 'bowlingAvg', 'bowlingS/R', 'bowlerEconomy', 'dotBalls%']]
    final_team = parameters.loc[players]
    
    final_team.replace(0, np.nan, inplace=True)

    total = final_team.mean(numeric_only=True)

    final_team.reset_index(inplace=True)

    # final_team = final_team.append(total, ignore_index=True).fillna('-')
    final_team.loc[len(final_team)] = total
    
    final_team.iloc[:, 3:] = round(final_team.iloc[:, 3:], 2)   # that one line
    final_team.iloc[len(players),0] = 'Total Performance'
    final_team.set_index('name', inplace=True)
    
    final_team.fillna('-', inplace=True) # if we keep this line before that line below this will not round up the remaining columns where values are null

    return final_team

# %%
players = ['Jos Buttler',
           'Alex Hales',
           'Rilee Rossouw',
           'Virat Kohli',
           'Suryakumar Yadav',
           'Glenn Maxwell',
           'Marcus Stoinis',
           # 'Hardik Pandya',
           # 'Sikandar Raza',
           'Mitchell Santner',
           'Shadab Khan',
           'Anrich Nortje',
           'Shaheen Shah Afridi',
           'Sam Curran']

build_team(players)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11884\1976966257.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   final_team.fillna('-', inplace=True) # if we keep this line before that line below this will not round up the remaining columns where values are null
#                        battingStyle                          bowlingStyle  \
# name
# Jos Buttler          Right hand Bat
# Alex Hales           Right hand Bat                      Right arm Medium
# Rilee Rossouw         Left hand Bat                    Right arm Offbreak
# Virat Kohli          Right hand Bat                      Right arm Medium
# Suryakumar Yadav     Right hand Bat  Right arm Medium, Right arm Offbreak
# Glenn Maxwell        Right hand Bat                    Right arm Offbreak
# Marcus Stoinis       Right hand Bat                      Right arm Medium
# Mitchell Santner      Left hand Bat                Slow Left arm Orthodox
# Shadab Khan          Right hand Bat                              Legbreak
# Anrich Nortje        Right hand Bat                        Right arm Fast
# Shaheen Shah Afridi   Left hand Bat                         Left arm Fast
# Sam Curran            Left hand Bat                  Left arm Medium fast
# Total Performance                 -                                     -
#
#                      battingAvg  battingS/R  boundary%  avgBallsFaced  \
# name
# Jos Buttler               45.00      144.23      61.33          26.00
# Alex Hales                42.40      147.22      64.15          24.00
# Rilee Rossouw             35.25      169.88      63.83          20.75
# Virat Kohli               98.67      136.41      50.00          36.17
# Suryakumar Yadav          59.75      189.68      66.11          21.00
# Glenn Maxwell             39.33      161.64      67.80          18.25
# Marcus Stoinis            42.00      161.54      65.08          19.50
# Mitchell Santner          27.00      168.75      44.44           5.33
# Shadab Khan               24.50      168.97      59.18           9.67
# Anrich Nortje              5.00       83.33      80.00           3.00
# Shaheen Shah Afridi       11.00      183.33      63.64           4.00
# Sam Curran                12.00       85.71      50.00           7.00
# Total Performance         36.82      150.06      61.30          16.22
#
#                     bowlingAvg bowlingS/R bowlerEconomy dotBalls%
# name
# Jos Buttler                  -          -             -         -
# Alex Hales                   -          -             -         -
# Rilee Rossouw                -          -             -         -
# Virat Kohli                  -          -             -         -
# Suryakumar Yadav             -          -             -         -
# Glenn Maxwell             6.33       6.33           6.0     42.11
# Marcus Stoinis            87.0       54.0          9.67     14.81
# Mitchell Santner         14.33      13.33          6.45     40.83
# Shadab Khan               15.0      14.18          6.35     37.82
# Anrich Nortje             8.55       9.55          5.37     55.24
# Shaheen Shah Afridi      14.09      13.73          6.16     46.36
# Sam Curran               11.38      10.46          6.53     48.53
# Total Performance        22.38      17.37          6.65     40.81

# %% [markdown]
# figures of each players in a playing team given below
# - if we need a team which is good at batting then we  will go  for  Marcus  Stoinis --> 36.82  150.06  61.30  16.22  22.38  17.37  6.65  40.81
#
# - if we need a team which is good at fast bowling then we will go for Hardik Pandya  --> 35.46  147.59  60.43  16.21  12.56  11.58  6.42  44.25
#
# - if we need a team which is good at spin bowling then we will go for Sikandar Raza  --> 35.61  148.93  60.82  16.14  12.18  11.71  6.19  43.26

# %% [markdown]
# #  Step 5 :- Communicating Results

# %% [markdown]
# - from the above dataframe we can conclude that our team has been qualifies the objectives that we set.
# - the team is able to score 180+ runs with the batting strike rate of 150+.
# - the good batting average and average balls faced by each players results the team will survive it does not fall to all out.
# - good boundary percentage results the team is full of hard hitters who gets most of the runs through boundaries....
# - in bowling point of view it performs very well.
# - if we not bowl stoinis we plays with 3 spinners and 3 fasters
# - our bowling average falls below to 11.61 that is our team is capable of taking wicket for each 11.61 balls
# - our bowling strike rate falls below to 11.26 that is our team is capable of taking wicket for each 11.26 runs....
# - in case if we need an extra bowler we can go with `Hardik Pandya` who bowls medium fast and `Sikandar Raza` who bowls offbreak
